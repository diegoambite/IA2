# %% [markdown]
# # Práctica 1. Aprendizaje automático

# %% [markdown]
# Grupo 16: Adina Han, Diego Ambite

# %% [markdown]
# ## Parte 3: Regresión

# %% [markdown]
# 0. Antes de empezar vamos a eliminar la variable “Region” del conjunto de datos, ya que no la usaremos para predecir.
# Además, utiliza la función dropna que elimina de un data frame todas las filas (es decir, observaciones) que tienen un valor perdido (na quiere decir not available) para alguna variable. De esta forma, no tendrás que preocuparte por imputar un valor a dichas observaciones. Asegúrate de que el dataframe resultante no tiene la variable Region, ni valores perdidos.

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
countries = pd.read_csv('countries.csv', index_col = 0) 
countries
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
# ...                                              ...         ...
# West Bank        NEAR EAST                               2460492
# Western Sahara   NORTHERN AFRICA                          273008
# Yemen            NEAR EAST                              21456188
# Zambia           SUB-SAHARAN AFRICA                     11502010
# Zimbabwe         SUB-SAHARAN AFRICA                     12236805
#
#                  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                        48.0
# Albania                   28748                       124.6
# Algeria                 2381740                        13.8
# American Samoa              199                       290.4
# Andorra                     468                       152.1
# ...                         ...                         ...
# West Bank                  5860                       419.9
# Western Sahara           266000                         1.0
# Yemen                    527970                        40.6
# Zambia                   752614                        15.3
# Zimbabwe                 390580                        31.3
#
#                  Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                              0.00          23.06
# Albania                                  1.26          -4.93
# Algeria                                  0.04          -0.39
# American Samoa                          58.29         -20.71
# Andorra                                  0.00           6.60
# ...                                       ...            ...
# West Bank                                0.00           2.98
# Western Sahara                           0.42            NaN
# Yemen                                    0.36           0.00
# Zambia                                   0.00           0.00
# Zimbabwe                                 0.00           0.00
#
#                  Infant mortality (per 1000 births)  GDP (USD per capita)  \
# Country
# Afghanistan                                  163.07                 700.0
# Albania                                       21.52                4500.0
# Algeria                                       31.00                6000.0
# American Samoa                                 9.27                8000.0
# Andorra                                        4.05               19000.0
# ...                                             ...                   ...
# West Bank                                     19.62                 800.0
# Western Sahara                                  NaN                   NaN
# Yemen                                         61.50                 800.0
# Zambia                                        88.29                 800.0
# Zimbabwe                                      67.69                1900.0
#
#                  Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  \
# Country
# Afghanistan              36.0                3.2       12.13       0.22
# Albania                  86.5               71.2       21.09       4.42
# Algeria                  70.0               78.1        3.22       0.25
# American Samoa           97.0              259.5       10.00      15.00
# Andorra                 100.0              497.2        2.22       0.00
# ...                       ...                ...         ...        ...
# West Bank                 NaN              145.2       16.90      18.97
# Western Sahara            NaN                NaN        0.02       0.00
# Yemen                    50.2               37.2        2.78       0.24
# Zambia                   80.6                8.2        7.08       0.03
# Zimbabwe                 90.7               26.8        8.32       0.34
#
#                  Other (%)  Climate  Birthrate  Deathrate  Agriculture  \
# Country
# Afghanistan          87.65      1.0      46.60      20.34        0.380
# Albania              74.49      3.0      15.11       5.22        0.232
# Algeria              96.53      1.0      17.14       4.61        0.101
# American Samoa       75.00      2.0      22.46       3.27          NaN
# Andorra              97.78      3.0       8.71       6.25          NaN
# ...                    ...      ...        ...        ...          ...
# West Bank            64.13      3.0      31.67       3.92        0.090
# Western Sahara       99.98      1.0        NaN        NaN          NaN
# Yemen                96.98      1.0      42.89       8.30        0.135
# Zambia               92.90      2.0      41.00      19.93        0.220
# Zimbabwe             91.34      2.0      28.01      21.84        0.179
#
#                  Industry  Service
# Country
# Afghanistan         0.240    0.380
# Albania             0.188    0.579
# Algeria             0.600    0.298
# American Samoa        NaN      NaN
# Andorra               NaN      NaN
# ...                   ...      ...
# West Bank           0.280    0.630
# Western Sahara        NaN    0.400
# Yemen               0.472    0.393
# Zambia              0.290    0.489
# Zimbabwe            0.243    0.579
#
# [227 rows x 19 columns]

# %%
countries.columns
# Out:
# Index(['Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
#        'Coastline (coast/area ratio)', 'Net migration',
#        'Infant mortality (per 1000 births)', 'GDP (USD per capita)',
#        'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)',
#        'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture',
#        'Industry', 'Service'],
#       dtype='object')

# %%
countries.shape
# Out:
# (227, 19)

# %%
countries['GDP'] = countries['GDP (USD per capita)']
countries.drop(['GDP (USD per capita)'], axis='columns', inplace=True)
countries.head()
# Out:
#                                               Region  Population  \
# Country
# Afghanistan            ASIA (EX. NEAR EAST)             31056997
# Albania          EASTERN EUROPE                          3581655
# Algeria          NORTHERN AFRICA                        32930091
# American Samoa   OCEANIA                                   57794
# Andorra          WESTERN EUROPE                            71201
#
#                  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan              647500                        48.0
# Albania                   28748                       124.6
# Algeria                 2381740                        13.8
# American Samoa              199                       290.4
# Andorra                     468                       152.1
#
#                  Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                              0.00          23.06
# Albania                                  1.26          -4.93
# Algeria                                  0.04          -0.39
# American Samoa                          58.29         -20.71
# Andorra                                  0.00           6.60
#
#                  Infant mortality (per 1000 births)  Literacy (%)  \
# Country
# Afghanistan                                  163.07          36.0
# Albania                                       21.52          86.5
# Algeria                                       31.00          70.0
# American Samoa                                 9.27          97.0
# Andorra                                        4.05         100.0
#
#                  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# Country
# Afghanistan                    3.2       12.13       0.22      87.65      1.0
# Albania                       71.2       21.09       4.42      74.49      3.0
# Algeria                       78.1        3.22       0.25      96.53      1.0
# American Samoa               259.5       10.00      15.00      75.00      2.0
# Andorra                      497.2        2.22       0.00      97.78      3.0
#
#                  Birthrate  Deathrate  Agriculture  Industry  Service      GDP
# Country
# Afghanistan          46.60      20.34        0.380     0.240    0.380    700.0
# Albania              15.11       5.22        0.232     0.188    0.579   4500.0
# Algeria              17.14       4.61        0.101     0.600    0.298   6000.0
# American Samoa       22.46       3.27          NaN       NaN      NaN   8000.0
# Andorra               8.71       6.25          NaN       NaN      NaN  19000.0

# %%
countries.drop(['Region'], axis='columns', inplace=True)

# %%
countries.describe().transpose()
# Out:
#                                     count          mean           std  \
# Population                          227.0  2.874028e+07  1.178913e+08
# Area (sq. mi.)                      227.0  5.982270e+05  1.790282e+06
# Pop. Density (per sq. mi.)          227.0  3.790471e+02  1.660186e+03
# Coastline (coast/area ratio)        227.0  2.116533e+01  7.228686e+01
# Net migration                       224.0  3.812500e-02  4.889269e+00
# Infant mortality (per 1000 births)  224.0  3.550696e+01  3.538990e+01
# Literacy (%)                        209.0  8.283828e+01  1.972217e+01
# Phones (per 1000)                   223.0  2.360614e+02  2.279918e+02
# Arable (%)                          225.0  1.379711e+01  1.304040e+01
# Crops (%)                           225.0  4.564222e+00  8.361470e+00
# Other (%)                           225.0  8.163831e+01  1.614083e+01
# Climate                             205.0  2.139024e+00  6.993968e-01
# Birthrate                           224.0  2.211473e+01  1.117672e+01
# Deathrate                           223.0  9.241345e+00  4.990026e+00
# Agriculture                         212.0  1.508443e-01  1.467980e-01
# Industry                            211.0  2.827109e-01  1.382722e-01
# Service                             212.0  5.652830e-01  1.658410e-01
# GDP                                 226.0  9.689823e+03  1.004914e+04
#
#                                          min           25%          50%  \
# Population                          7026.000  437624.00000  4786994.000
# Area (sq. mi.)                         2.000    4647.50000    86600.000
# Pop. Density (per sq. mi.)             0.000      29.15000       78.800
# Coastline (coast/area ratio)           0.000       0.10000        0.730
# Net migration                        -20.990      -0.92750        0.000
# Infant mortality (per 1000 births)     2.290       8.15000       21.000
# Literacy (%)                          17.600      70.60000       92.500
# Phones (per 1000)                      0.200      37.80000      176.200
# Arable (%)                             0.000       3.22000       10.420
# Crops (%)                              0.000       0.19000        1.030
# Other (%)                             33.330      71.65000       85.700
# Climate                                1.000       2.00000        2.000
# Birthrate                              7.290      12.67250       18.790
# Deathrate                              2.290       5.91000        7.840
# Agriculture                            0.000       0.03775        0.099
# Industry                               0.020       0.19300        0.272
# Service                                0.062       0.42925        0.571
# GDP                                  500.000    1900.00000     5550.000
#
#                                              75%           max
# Population                          1.749777e+07  1.313974e+09
# Area (sq. mi.)                      4.418110e+05  1.707520e+07
# Pop. Density (per sq. mi.)          1.901500e+02  1.627150e+04
# Coastline (coast/area ratio)        1.034500e+01  8.706600e+02
# Net migration                       9.975000e-01  2.306000e+01
# Infant mortality (per 1000 births)  5.570500e+01  1.911900e+02
# Literacy (%)                        9.800000e+01  1.000000e+02
# Phones (per 1000)                   3.896500e+02  1.035600e+03
# Arable (%)                          2.000000e+01  6.211000e+01
# Crops (%)                           4.440000e+00  5.068000e+01
# Other (%)                           9.544000e+01  1.000000e+02
# Climate                             3.000000e+00  4.000000e+00
# Birthrate                           2.982000e+01  5.073000e+01
# Deathrate                           1.060500e+01  2.974000e+01
# Agriculture                         2.210000e-01  7.690000e-01
# Industry                            3.410000e-01  9.060000e-01
# Service                             6.785000e-01  9.540000e-01
# GDP                                 1.570000e+04  5.510000e+04

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, Afghanistan  to Zimbabwe
# Data columns (total 18 columns):
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null float64
# Coastline (coast/area ratio)          227 non-null float64
# Net migration                         224 non-null float64
# Infant mortality (per 1000 births)    224 non-null float64
# Literacy (%)                          209 non-null float64
# Phones (per 1000)                     223 non-null float64
# Arable (%)                            225 non-null float64
# Crops (%)                             225 non-null float64
# Other (%)                             225 non-null float64
# Climate                               205 non-null float64
# Birthrate                             224 non-null float64
# Deathrate                             223 non-null float64
# Agriculture                           212 non-null float64
# Industry                              211 non-null float64
# Service                               212 non-null float64
# GDP                                   226 non-null float64
# dtypes: float64(16), int64(2)
# memory usage: 33.7+ KB

# %%
countries.dropna()
# Out:
#                     Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan           31056997          647500                        48.0
# Albania                3581655           28748                       124.6
# Algeria               32930091         2381740                        13.8
# Anguilla                 13477             102                       132.1
# Antigua & Barbuda        69108             443                       156.0
# ...                        ...             ...                         ...
# Venezuela             25730435          912050                        28.2
# Vietnam               84402966          329560                       256.1
# Yemen                 21456188          527970                        40.6
# Zambia                11502010          752614                        15.3
# Zimbabwe              12236805          390580                        31.3
#
#                     Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                                 0.00          23.06
# Albania                                     1.26          -4.93
# Algeria                                     0.04          -0.39
# Anguilla                                   59.80          10.76
# Antigua & Barbuda                          34.54          -6.15
# ...                                          ...            ...
# Venezuela                                   0.31          -0.04
# Vietnam                                     1.05          -0.45
# Yemen                                       0.36           0.00
# Zambia                                      0.00           0.00
# Zimbabwe                                    0.00           0.00
#
#                     Infant mortality (per 1000 births)  Literacy (%)  \
# Country
# Afghanistan                                     163.07          36.0
# Albania                                          21.52          86.5
# Algeria                                          31.00          70.0
# Anguilla                                         21.03          95.0
# Antigua & Barbuda                                19.46          89.0
# ...                                                ...           ...
# Venezuela                                        22.20          93.4
# Vietnam                                          25.95          90.3
# Yemen                                            61.50          50.2
# Zambia                                           88.29          80.6
# Zimbabwe                                         67.69          90.7
#
#                     Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# Country
# Afghanistan                       3.2       12.13       0.22      87.65
# Albania                          71.2       21.09       4.42      74.49
# Algeria                          78.1        3.22       0.25      96.53
# Anguilla                        460.0        0.00       0.00     100.00
# Antigua & Barbuda               549.9       18.18       4.55      77.27
# ...                               ...         ...        ...        ...
# Venezuela                       140.1        2.95       0.92      96.13
# Vietnam                         187.7       19.97       5.95      74.08
# Yemen                            37.2        2.78       0.24      96.98
# Zambia                            8.2        7.08       0.03      92.90
# Zimbabwe                         26.8        8.32       0.34      91.34
#
#                     Climate  Birthrate  Deathrate  Agriculture  Industry  \
# Country
# Afghanistan             1.0      46.60      20.34        0.380     0.240
# Albania                 3.0      15.11       5.22        0.232     0.188
# Algeria                 1.0      17.14       4.61        0.101     0.600
# Anguilla                2.0      14.17       5.34        0.040     0.180
# Antigua & Barbuda       2.0      16.93       5.37        0.038     0.220
# ...                     ...        ...        ...          ...       ...
# Venezuela               2.0      18.71       4.92        0.040     0.419
# Vietnam                 2.0      16.86       6.22        0.209     0.410
# Yemen                   1.0      42.89       8.30        0.135     0.472
# Zambia                  2.0      41.00      19.93        0.220     0.290
# Zimbabwe                2.0      28.01      21.84        0.179     0.243
#
#                     Service      GDP
# Country
# Afghanistan           0.380    700.0
# Albania               0.579   4500.0
# Algeria               0.298   6000.0
# Anguilla              0.780   8600.0
# Antigua & Barbuda     0.743  11000.0
# ...                     ...      ...
# Venezuela             0.541   4800.0
# Vietnam               0.381   2500.0
# Yemen                 0.393    800.0
# Zambia                0.489    800.0
# Zimbabwe              0.579   1900.0
#
# [179 rows x 18 columns]

# %% [markdown]
# #### Tras cargar el fichero y realizar las modificaciones requeridas podemos observar el conjunto de datos sin la variable Region y sin los valores no disponibles.

# %% [markdown]
# 1. Describe el conjunto de datos tal y como se indica más arriba y extrae algunas conclusiones de las variables, especialmente a la matriz de gráficos de dispersión y al coeficiente de correlación de la variable objetivo (GDP) con el resto de variables. ¿Hay variables que tengan una relación clara con ella?

# %% [markdown]
# #### El conjunto describe, para un total de 227 paises, la situacion de cada uno de estos paises con respecto a un conjunto de 18 caracteristicas, como su población, su area en millas cuadradas, su densidad de población en personas por milla cuadrada de territorio, etc.
# #### A continuación se muestra la  totalidad de las caracteristicas y las unidades usadas para ello.

# %%
countries.keys()
# Out:
# Index(['Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)',
#        'Coastline (coast/area ratio)', 'Net migration',
#        'Infant mortality (per 1000 births)', 'Literacy (%)',
#        'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate',
#        'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDP'],
#       dtype='object')

# %% [markdown]
# #### De entre ellas vamos a seleccionar los que consideramos que estan mas relacionados con el GDP para realizar un estudio mas pormenorizado de ellos.

# %%
correl=countries.corr()
correl
# Out:
#                                     Population  Area (sq. mi.)  \
# Population                            1.000000        0.469985
# Area (sq. mi.)                        0.469985        1.000000
# Pop. Density (per sq. mi.)           -0.028190       -0.066917
# Coastline (coast/area ratio)         -0.068199       -0.095627
# Net migration                         0.000011        0.047470
# Infant mortality (per 1000 births)    0.023003       -0.007163
# Literacy (%)                         -0.043481        0.035994
# Phones (per 1000)                    -0.030819        0.053403
# Arable (%)                            0.188251       -0.079714
# Crops (%)                            -0.060757       -0.143916
# Other (%)                            -0.120606        0.138974
# Climate                              -0.026546       -0.117134
# Birthrate                            -0.045090       -0.066423
# Deathrate                            -0.028367        0.040079
# Agriculture                           0.000376       -0.050640
# Industry                              0.099333        0.121565
# Service                              -0.080852       -0.054369
# GDP                                  -0.039324        0.072185
#
#                                     Pop. Density (per sq. mi.)  \
# Population                                           -0.028190
# Area (sq. mi.)                                       -0.066917
# Pop. Density (per sq. mi.)                            1.000000
# Coastline (coast/area ratio)                          0.241690
# Net migration                                         0.178038
# Infant mortality (per 1000 births)                   -0.144238
# Literacy (%)                                          0.097230
# Phones (per 1000)                                     0.280172
# Arable (%)                                           -0.081015
# Crops (%)                                            -0.031661
# Other (%)                                             0.081859
# Climate                                               0.009064
# Birthrate                                            -0.159192
# Deathrate                                            -0.070045
# Agriculture                                          -0.107142
# Industry                                             -0.139803
# Service                                               0.248774
# GDP                                                   0.195773
#
#                                     Coastline (coast/area ratio)  \
# Population                                             -0.068199
# Area (sq. mi.)                                         -0.095627
# Pop. Density (per sq. mi.)                              0.241690
# Coastline (coast/area ratio)                            1.000000
# Net migration                                          -0.134145
# Infant mortality (per 1000 births)                     -0.136577
# Literacy (%)                                            0.117095
# Phones (per 1000)                                       0.152129
# Arable (%)                                             -0.120772
# Crops (%)                                               0.341820
# Other (%)                                              -0.079494
# Climate                                                -0.032579
# Birthrate                                              -0.075765
# Deathrate                                              -0.161866
# Agriculture                                            -0.030250
# Industry                                               -0.199995
# Service                                                 0.196528
# GDP                                                     0.049118
#
#                                     Net migration  \
# Population                               0.000011
# Area (sq. mi.)                           0.047470
# Pop. Density (per sq. mi.)               0.178038
# Coastline (coast/area ratio)            -0.134145
# Net migration                            1.000000
# Infant mortality (per 1000 births)      -0.025015
# Literacy (%)                            -0.008761
# Phones (per 1000)                        0.239601
# Arable (%)                              -0.058170
# Crops (%)                               -0.347968
# Other (%)                                0.225299
# Climate                                 -0.015170
# Birthrate                               -0.066537
# Deathrate                                0.033611
# Agriculture                             -0.116719
# Industry                                -0.026324
# Service                                  0.127134
# GDP                                      0.382461
#
#                                     Infant mortality (per 1000 births)  \
# Population                                                    0.023003
# Area (sq. mi.)                                               -0.007163
# Pop. Density (per sq. mi.)                                   -0.144238
# Coastline (coast/area ratio)                                 -0.136577
# Net migration                                                -0.025015
# Infant mortality (per 1000 births)                            1.000000
# Literacy (%)                                                 -0.765536
# Phones (per 1000)                                            -0.672312
# Arable (%)                                                   -0.113859
# Crops (%)                                                    -0.062366
# Other (%)                                                     0.124100
# Climate                                                      -0.374406
# Birthrate                                                     0.845764
# Deathrate                                                     0.656338
# Agriculture                                                   0.709475
# Industry                                                      0.003322
# Service                                                      -0.633982
# GDP                                                          -0.600774
#
#                                     Literacy (%)  Phones (per 1000)  \
# Population                             -0.043481          -0.030819
# Area (sq. mi.)                          0.035994           0.053403
# Pop. Density (per sq. mi.)              0.097230           0.280172
# Coastline (coast/area ratio)            0.117095           0.152129
# Net migration                          -0.008761           0.239601
# Infant mortality (per 1000 births)     -0.765536          -0.672312
# Literacy (%)                            1.000000           0.601935
# Phones (per 1000)                       0.601935           1.000000
# Arable (%)                              0.105021           0.061022
# Crops (%)                               0.042825          -0.152420
# Other (%)                              -0.107563           0.029900
# Climate                                 0.392081           0.402161
# Birthrate                              -0.790846          -0.724614
# Deathrate                              -0.393946          -0.260309
# Agriculture                            -0.609638          -0.601739
# Industry                                0.064733          -0.152452
# Service                                 0.494607           0.683934
# GDP                                     0.513144           0.834499
#
#                                     Arable (%)  Crops (%)  Other (%)  \
# Population                            0.188251  -0.060757  -0.120606
# Area (sq. mi.)                       -0.079714  -0.143916   0.138974
# Pop. Density (per sq. mi.)           -0.081015  -0.031661   0.081859
# Coastline (coast/area ratio)         -0.120772   0.341820  -0.079494
# Net migration                        -0.058170  -0.347968   0.225299
# Infant mortality (per 1000 births)   -0.113859  -0.062366   0.124100
# Literacy (%)                          0.105021   0.042825  -0.107563
# Phones (per 1000)                     0.061022  -0.152420   0.029900
# Arable (%)                            1.000000   0.094361  -0.856763
# Crops (%)                             0.094361   1.000000  -0.594254
# Other (%)                            -0.856763  -0.594254   1.000000
# Climate                               0.380031   0.004343  -0.305629
# Birthrate                            -0.186823   0.120687   0.088586
# Deathrate                             0.053472  -0.204961   0.062145
# Agriculture                          -0.034822   0.052941   0.001078
# Industry                             -0.063618  -0.117715   0.112091
# Service                               0.091126   0.053946  -0.101518
# GDP                                   0.019768  -0.219229   0.097828
#
#                                      Climate  Birthrate  Deathrate  \
# Population                         -0.026546  -0.045090  -0.028367
# Area (sq. mi.)                     -0.117134  -0.066423   0.040079
# Pop. Density (per sq. mi.)          0.009064  -0.159192  -0.070045
# Coastline (coast/area ratio)       -0.032579  -0.075765  -0.161866
# Net migration                      -0.015170  -0.066537   0.033611
# Infant mortality (per 1000 births) -0.374406   0.845764   0.656338
# Literacy (%)                        0.392081  -0.790846  -0.393946
# Phones (per 1000)                   0.402161  -0.724614  -0.260309
# Arable (%)                          0.380031  -0.186823   0.053472
# Crops (%)                           0.004343   0.120687  -0.204961
# Other (%)                          -0.305629   0.088586   0.062145
# Climate                             1.000000  -0.455097   0.011131
# Birthrate                          -0.455097   1.000000   0.395302
# Deathrate                           0.011131   0.395302   1.000000
# Agriculture                        -0.210642   0.678207   0.382528
# Industry                           -0.094945  -0.056953   0.026864
# Service                             0.272518  -0.557694  -0.359717
# GDP                                 0.340791  -0.650137  -0.201661
#
#                                     Agriculture  Industry   Service       GDP
# Population                             0.000376  0.099333 -0.080852 -0.039324
# Area (sq. mi.)                        -0.050640  0.121565 -0.054369  0.072185
# Pop. Density (per sq. mi.)            -0.107142 -0.139803  0.248774  0.195773
# Coastline (coast/area ratio)          -0.030250 -0.199995  0.196528  0.049118
# Net migration                         -0.116719 -0.026324  0.127134  0.382461
# Infant mortality (per 1000 births)     0.709475  0.003322 -0.633982 -0.600774
# Literacy (%)                          -0.609638  0.064733  0.494607  0.513144
# Phones (per 1000)                     -0.601739 -0.152452  0.683934  0.834499
# Arable (%)                            -0.034822 -0.063618  0.091126  0.019768
# Crops (%)                              0.052941 -0.117715  0.053946 -0.219229
# Other (%)                              0.001078  0.112091 -0.101518  0.097828
# Climate                               -0.210642 -0.094945  0.272518  0.340791
# Birthrate                              0.678207 -0.056953 -0.557694 -0.650137
# Deathrate                              0.382528  0.026864 -0.359717 -0.201661
# Agriculture                            1.000000 -0.322909 -0.617039 -0.586769
# Industry                              -0.322909  1.000000 -0.544594 -0.028926
# Service                               -0.617039 -0.544594  1.000000  0.550216
# GDP                                   -0.586769 -0.028926  0.550216  1.000000

# %%
correl['GDP']
# Out:
# Population                           -0.039324
# Area (sq. mi.)                        0.072185
# Pop. Density (per sq. mi.)            0.195773
# Coastline (coast/area ratio)          0.049118
# Net migration                         0.382461
# Infant mortality (per 1000 births)   -0.600774
# Literacy (%)                          0.513144
# Phones (per 1000)                     0.834499
# Arable (%)                            0.019768
# Crops (%)                            -0.219229
# Other (%)                             0.097828
# Climate                               0.340791
# Birthrate                            -0.650137
# Deathrate                            -0.201661
# Agriculture                          -0.586769
# Industry                             -0.028926
# Service                               0.550216
# GDP                                   1.000000
# Name: GDP, dtype: float64

# %% [markdown]
# #### Ordenamos los valores que hemos obtenido para el coeficiente de correlación.

# %%
correl['GDP'].sort_values(ascending=False)
# Out:
# GDP                                   1.000000
# Phones (per 1000)                     0.834499
# Service                               0.550216
# Literacy (%)                          0.513144
# Net migration                         0.382461
# Climate                               0.340791
# Pop. Density (per sq. mi.)            0.195773
# Other (%)                             0.097828
# Area (sq. mi.)                        0.072185
# Coastline (coast/area ratio)          0.049118
# Arable (%)                            0.019768
# Industry                             -0.028926
# Population                           -0.039324
# Deathrate                            -0.201661
# Crops (%)                            -0.219229
# Agriculture                          -0.586769
# Infant mortality (per 1000 births)   -0.600774
# Birthrate                            -0.650137
# Name: GDP, dtype: float64

# %%
correl[correl['GDP'] > 0.3]['GDP'].sort_values(ascending=False).drop('GDP')
# Out:
# Phones (per 1000)    0.834499
# Service              0.550216
# Literacy (%)         0.513144
# Net migration        0.382461
# Climate              0.340791
# Name: GDP, dtype: float64

# %%
sns.regplot(x="GDP", y = "Phones (per 1000)", data=countries)

# %%
sns.regplot(x="GDP", y = "Service", data=countries)

# %%
sns.regplot(x="GDP", y = "Literacy (%)", data=countries)

# %%
sns.regplot(x="GDP", y = "Net migration", data=countries)

# %%
countries.GDP.hist()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20,12))
plt.subplots_adjust(hspace=0.4)

corr_to_gdp = pd.Series()
for col in countries.columns.values[2:]:
    if ((col!='GDP')&(col!='Climate')):
        corr_to_gdp[col] = countries['GDP'].corr(countries[col])
abs_corr_to_gdp = corr_to_gdp.abs().sort_values(ascending=False)
corr_to_gdp = corr_to_gdp.loc[abs_corr_to_gdp.index]

for i in range(2):
    for j in range(3):
        sns.regplot(x=corr_to_gdp.index.values[i*3+j], y='GDP', data=countries,
                   ax=axes[i,j], fit_reg=False, marker='.')
        title = 'correlation='+str(corr_to_gdp[i*3+j])
        axes[i,j].set_title(title)
axes[1,2].set_xlim(0,102)
plt.show()

# %%
related_columns_set = []
pair_columns = []
for col in correl.columns:
    #print(col)
    for idx in correl.index:
        #print(idx)
        if(correl.loc[idx,col] >  0.4 or correl.loc[idx,col] < -0.4) and correl.loc[idx,col] != 1:
            if(idx+"-"+col+":"+str(correl.loc[idx,col]) not in related_columns_set):
                related_columns_set.append(col+"-"+idx+":"+str(correl.loc[idx,col]))
                pair_columns.append([col,idx])
                print(col,"-", idx,":", correl.loc[idx,col])
fig, axes = plt.subplots(nrows=14, ncols=2, figsize=(16,48))
i = 0
for pair in pair_columns:    
    #print(i//2, i%2)
    countries.plot(x=pair[0],y=pair[1], kind="scatter", ax=axes[i//2, i%2])
    i += 1
# Out:
# Population - Area (sq. mi.) : 0.4699850837184817
# Infant mortality (per 1000 births) - Literacy (%) : -0.7655358136241809
# Infant mortality (per 1000 births) - Phones (per 1000) : -0.6723118556711715
# Infant mortality (per 1000 births) - Birthrate : 0.8457641944976056
# Infant mortality (per 1000 births) - Deathrate : 0.6563380061326066
# Infant mortality (per 1000 births) - Agriculture : 0.7094750445695917
# Infant mortality (per 1000 births) - Service : -0.6339824701168715
# Infant mortality (per 1000 births) - GDP : -0.6007739662612172
# Literacy (%) - Phones (per 1000) : 0.6019350049670077
# Literacy (%) - Birthrate : -0.7908461681610454
# Literacy (%) - Agriculture : -0.6096380702072316
# Literacy (%) - Service : 0.4946074520473804
# Literacy (%) - GDP : 0.513143541309271
# Phones (per 1000) - Climate : 0.40216068357686774
# Phones (per 1000) - Birthrate : -0.7246144139500446
# Phones (per 1000) - Agriculture : -0.601738880745303
# Phones (per 1000) - Service : 0.6839341196035666
# Phones (per 1000) - GDP : 0.834499275414044
# Arable (%) - Other (%) : -0.8567625920902615
# Crops (%) - Other (%) : -0.5942544139586196
# Climate - Birthrate : -0.4550973586169035
# Birthrate - Agriculture : 0.6782071350548277
# Birthrate - Service : -0.5576939105217485
# Birthrate - GDP : -0.6501370279422611
# Agriculture - Service : -0.6170388230633276
# Agriculture - GDP : -0.5867685622247596
# Industry - Service : -0.5445940699994951
# Service - GDP : 0.5502157117307866

# %% [markdown]
# #### El coeficiente de correlación es una medida del grado de dependencia lineal entre 2 variables y su valor oscila entre -1 y 1. #### Un valor de 1 significa que la ecuación lineal describe a la prefección la relación entre las variables. Podemos ver esto se consigue si usamos la variables GDP consigo misma, ya que la ecuación lineal es capaz de describir a la perfección la relación de una variable consigo misma.
# #### Por lo tanto significa que cuanto más alto el valor obtenido para el coeficiente de correlación más correlacionadas van a ser esas variables con el GDP. Entonces las variables más correlacionadas con el GDP que son las siguientes:
#     * Phones (per 1000)
#     * Service
#     * Literacy (%)
#     * Net migration
#     * Climate
# #### Esto lo podemos comprobar también en las gráficas de dispersión de puntos y vemos que para el caso de las variables GDP/Phones (per 1000) tienen una relación clara,ya que el crecimiento de una implica el creciemiento de la otra.
# #### En el caso de las variables seleccionadas podemos ver que  las variables sigue correlacionadas pero no tanto fuertemente como la anterior. Podemos observar que hay muchos valores que se alejan de la linea de regresión.

# %% [markdown]
# 2. Establece un criterio en base al coeficiente de correlación para filtrar aquellas variables que tengan poca relación (ya sea directa o inversa) con la variable objetivo. Di qué variables pasan tu filtro y qué coeficiente de correlación tienen con ella.

# %%
correl[correl['GDP'] < 0.0]['GDP'].sort_values(ascending=True)
# Out:
# Birthrate                            -0.650137
# Infant mortality (per 1000 births)   -0.600774
# Agriculture                          -0.586769
# Crops (%)                            -0.219229
# Deathrate                            -0.201661
# Population                           -0.039324
# Industry                             -0.028926
# Name: GDP, dtype: float64

# %%
sns.regplot(x="GDP", y="Birthrate", data = countries)

# %%
sns.regplot(x="GDP", y="Infant mortality (per 1000 births)", data = countries)

# %%
sns.regplot(x="GDP", y="Agriculture", data = countries)

# %%
sns.regplot(x="GDP", y="Crops (%)", data = countries)

# %%
sns.regplot(x="GDP", y="Deathrate", data = countries)

# %% [markdown]
# #### Para filtrar las variables que tienen poca correlación con la variables objetivo hemos utilizado el coeficiente de correlación calculado anteriormente y hemos elegido solo los valores negativos, ya que un valor muy bajo significa que la correlación es muy baja. Las variables que han pasado este filtro son las siguientes:
#     * Birthrate
#     * Infant mortality (per 1000 births)
#     * Agriculture
#     * Crops (%)
#     * Deathrate
#     * Population
#     * Industry
# #### Siendo la variable Birthrate la que menos correlación tiene con GDP.

# %% [markdown]
# 3. Considera si debes normalizar o estandarizar las variables antes para usar un perceptrón multicapa de decisión. Razona tu elección.

# %%
df = pd.DataFrame(data=countries) 
df
# Out:
#                  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan        31056997          647500                        48.0
# Albania             3581655           28748                       124.6
# Algeria            32930091         2381740                        13.8
# American Samoa        57794             199                       290.4
# Andorra               71201             468                       152.1
# ...                     ...             ...                         ...
# West Bank           2460492            5860                       419.9
# Western Sahara       273008          266000                         1.0
# Yemen              21456188          527970                        40.6
# Zambia             11502010          752614                        15.3
# Zimbabwe           12236805          390580                        31.3
#
#                  Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                              0.00          23.06
# Albania                                  1.26          -4.93
# Algeria                                  0.04          -0.39
# American Samoa                          58.29         -20.71
# Andorra                                  0.00           6.60
# ...                                       ...            ...
# West Bank                                0.00           2.98
# Western Sahara                           0.42            NaN
# Yemen                                    0.36           0.00
# Zambia                                   0.00           0.00
# Zimbabwe                                 0.00           0.00
#
#                  Infant mortality (per 1000 births)  Literacy (%)  \
# Country
# Afghanistan                                  163.07          36.0
# Albania                                       21.52          86.5
# Algeria                                       31.00          70.0
# American Samoa                                 9.27          97.0
# Andorra                                        4.05         100.0
# ...                                             ...           ...
# West Bank                                     19.62           NaN
# Western Sahara                                  NaN           NaN
# Yemen                                         61.50          50.2
# Zambia                                        88.29          80.6
# Zimbabwe                                      67.69          90.7
#
#                  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# Country
# Afghanistan                    3.2       12.13       0.22      87.65      1.0
# Albania                       71.2       21.09       4.42      74.49      3.0
# Algeria                       78.1        3.22       0.25      96.53      1.0
# American Samoa               259.5       10.00      15.00      75.00      2.0
# Andorra                      497.2        2.22       0.00      97.78      3.0
# ...                            ...         ...        ...        ...      ...
# West Bank                    145.2       16.90      18.97      64.13      3.0
# Western Sahara                 NaN        0.02       0.00      99.98      1.0
# Yemen                         37.2        2.78       0.24      96.98      1.0
# Zambia                         8.2        7.08       0.03      92.90      2.0
# Zimbabwe                      26.8        8.32       0.34      91.34      2.0
#
#                  Birthrate  Deathrate  Agriculture  Industry  Service      GDP
# Country
# Afghanistan          46.60      20.34        0.380     0.240    0.380    700.0
# Albania              15.11       5.22        0.232     0.188    0.579   4500.0
# Algeria              17.14       4.61        0.101     0.600    0.298   6000.0
# American Samoa       22.46       3.27          NaN       NaN      NaN   8000.0
# Andorra               8.71       6.25          NaN       NaN      NaN  19000.0
# ...                    ...        ...          ...       ...      ...      ...
# West Bank            31.67       3.92        0.090     0.280    0.630    800.0
# Western Sahara         NaN        NaN          NaN       NaN    0.400      NaN
# Yemen                42.89       8.30        0.135     0.472    0.393    800.0
# Zambia               41.00      19.93        0.220     0.290    0.489    800.0
# Zimbabwe             28.01      21.84        0.179     0.243    0.579   1900.0
#
# [227 rows x 18 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                     Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan           31056997          647500                        48.0
# Albania                3581655           28748                       124.6
# Algeria               32930091         2381740                        13.8
# Anguilla                 13477             102                       132.1
# Antigua & Barbuda        69108             443                       156.0
# ...                        ...             ...                         ...
# Venezuela             25730435          912050                        28.2
# Vietnam               84402966          329560                       256.1
# Yemen                 21456188          527970                        40.6
# Zambia                11502010          752614                        15.3
# Zimbabwe              12236805          390580                        31.3
#
#                     Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                                 0.00          23.06
# Albania                                     1.26          -4.93
# Algeria                                     0.04          -0.39
# Anguilla                                   59.80          10.76
# Antigua & Barbuda                          34.54          -6.15
# ...                                          ...            ...
# Venezuela                                   0.31          -0.04
# Vietnam                                     1.05          -0.45
# Yemen                                       0.36           0.00
# Zambia                                      0.00           0.00
# Zimbabwe                                    0.00           0.00
#
#                     Infant mortality (per 1000 births)  Literacy (%)  \
# Country
# Afghanistan                                     163.07          36.0
# Albania                                          21.52          86.5
# Algeria                                          31.00          70.0
# Anguilla                                         21.03          95.0
# Antigua & Barbuda                                19.46          89.0
# ...                                                ...           ...
# Venezuela                                        22.20          93.4
# Vietnam                                          25.95          90.3
# Yemen                                            61.50          50.2
# Zambia                                           88.29          80.6
# Zimbabwe                                         67.69          90.7
#
#                     Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# Country
# Afghanistan                       3.2       12.13       0.22      87.65
# Albania                          71.2       21.09       4.42      74.49
# Algeria                          78.1        3.22       0.25      96.53
# Anguilla                        460.0        0.00       0.00     100.00
# Antigua & Barbuda               549.9       18.18       4.55      77.27
# ...                               ...         ...        ...        ...
# Venezuela                       140.1        2.95       0.92      96.13
# Vietnam                         187.7       19.97       5.95      74.08
# Yemen                            37.2        2.78       0.24      96.98
# Zambia                            8.2        7.08       0.03      92.90
# Zimbabwe                         26.8        8.32       0.34      91.34
#
#                     Climate  Birthrate  Deathrate  Agriculture  Industry  \
# Country
# Afghanistan             1.0      46.60      20.34        0.380     0.240
# Albania                 3.0      15.11       5.22        0.232     0.188
# Algeria                 1.0      17.14       4.61        0.101     0.600
# Anguilla                2.0      14.17       5.34        0.040     0.180
# Antigua & Barbuda       2.0      16.93       5.37        0.038     0.220
# ...                     ...        ...        ...          ...       ...
# Venezuela               2.0      18.71       4.92        0.040     0.419
# Vietnam                 2.0      16.86       6.22        0.209     0.410
# Yemen                   1.0      42.89       8.30        0.135     0.472
# Zambia                  2.0      41.00      19.93        0.220     0.290
# Zimbabwe                2.0      28.01      21.84        0.179     0.243
#
#                     Service      GDP
# Country
# Afghanistan           0.380    700.0
# Albania               0.579   4500.0
# Algeria               0.298   6000.0
# Anguilla              0.780   8600.0
# Antigua & Barbuda     0.743  11000.0
# ...                     ...      ...
# Venezuela             0.541   4800.0
# Vietnam               0.381   2500.0
# Yemen                 0.393    800.0
# Zambia                0.489    800.0
# Zimbabwe              0.579   1900.0
#
# [179 rows x 18 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
scaler_x.fit(df)
countries_scaled=scaler_x.transform(df)
countries_scaled
# Out:
# array([[-0.02402789,  0.05986479, -0.17943007, ..., -0.3432598 ,
#         -1.05630628, -0.87611209],
#        [-0.23313231, -0.38471982, -0.123741  , ..., -0.7149083 ,
#          0.14824877, -0.48098449],
#        [-0.00977248,  1.30594788, -0.20429386, ...,  2.22969138,
#         -1.55265559, -0.32501307],
#        ...,
#        [-0.09709601, -0.0260197 , -0.18480996, ...,  1.3148643 ,
#         -0.97761675, -0.86571399],
#        [-0.17285349,  0.13539111, -0.20320335, ...,  0.01409453,
#         -0.39652487, -0.86571399],
#        [-0.16726125, -0.12473692, -0.19157116, ..., -0.32181854,
#          0.14824877, -0.75133495]])

# %%
scaler_y = StandardScaler()
data = countries_scaled[:,17] 
scaler_y.fit(data.reshape(-1, 1)) 
target_scaled=scaler_y.transform(data.reshape(-1, 1))

# %% [markdown]
# #### Hemos decidido normalizar los datos ya que las variables están en medidas diferentes. El tipo de escalado que hemos utilizado ha sido el escalado estandard y hemos escalado tanto las variables de entrada con la variable de salida. También hemos tomado en cuenta el hecho que al normalizar las variables disminuye el tiempo de entrenamiento y evita los "minimos locales".

# %% [markdown]
# 4. Configura una validación cruzada con k=5 y dos perceptrones multicapa
#
#       • MLP1 con una capa oculta de 200 neuronas
#
#       • MLP2 con dos capas ocultas de 50 neuronas cada una
#
# Pinta la curva de aprendizaje para cada perceptrón variando el parámetro alpha que controla el aprendizaje del perceptrón y determina el valor óptimo (es decir aquel que maximiza el Mean Square Error en negativo).
# Asegúrate de que no salen warnings indicando que no se ha alcanzado la convergencia durante el entrenamiento (basta con poner un número de max_iter suficientemente grande).
# ¿Alguno de los dos perceptrones domina al otro? ¿Por qué crees que se producen las diferencias?

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import numpy as np


regul_param_range = 10.0 ** -np.arange(1, 7) 

cv_scores_mean1=[]
cv_scores_mean2=[]
cv_scores_std1=[]
cv_scores_std2=[]

for regul_param in regul_param_range:
    print("regul_param", regul_param)
    # aumentamos el parámetro max_iter hasta que converja
    mlp1=MLPRegressor(hidden_layer_sizes=(200, ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    mlp2=MLPRegressor(hidden_layer_sizes=(50,50 ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    
    # El error es neg_mean_squared_error el MSE en negativo!! Más pequeño peor.
    scores1 = cross_val_score(mlp1, countries_scaled, target_scaled.ravel(), cv=5, scoring='neg_mean_squared_error')
    scores2 = cross_val_score(mlp2, countries_scaled, target_scaled.ravel(), cv=5, scoring='neg_mean_squared_error')
    cv_scores_mean1.append(scores1.mean())
    print("mean1", scores1.mean())
    cv_scores_mean2.append(scores2.mean())
    print("mean2", scores2.mean())
    cv_scores_std1.append(scores1.std())
    cv_scores_std2.append(scores2.std())
# Out:
# regul_param 0.1
# mean1 -0.019883554138594804
# mean2 -0.013560396991010807
# regul_param 0.01
# mean1 -0.024001305665342792
# mean2 -0.03474050233030067
# regul_param 0.001
# mean1 -0.024322006113129197
# mean2 -0.03480750933585922
# regul_param 0.0001
# mean1 -0.02432997841052429
# mean2 -0.034847274654502505
# regul_param 1e-05
# mean1 -0.024332184056544456
# mean2 -0.03456708334115867
# regul_param 1e-06
# mean1 -0.024332768901248174
# mean2 -0.03436942542054654

# %%
import matplotlib.pyplot as plt

# Dibujamos la línea de la exactitud media en las partes de test
# Como el 
plt.plot(np.log10(regul_param_range), cv_scores_mean1, color="g", label="Test")

# Dibujamos la banda de la desviación típica
lower_limit=np.array(cv_scores_mean1)-np.array(cv_scores_std1)
upper_limit=np.array(cv_scores_mean1)+np.array(cv_scores_std1)
plt.fill_between(np.log10(regul_param_range), lower_limit, upper_limit, color="#DDDDDD")

# Creamos el gráfico
plt.title("Curva de aprendizaje")
plt.xlabel("Regularización 10^{-X}"), plt.ylabel("negative MSE"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dibujamos la línea de la exactitud media en las partes de test
# Como el 
plt.plot(np.log10(regul_param_range), cv_scores_mean2, color="g", label="Test")

# Dibujamos la banda de la desviación típica
lower_limit=np.array(cv_scores_mean2)-np.array(cv_scores_std2)
upper_limit=np.array(cv_scores_mean2)+np.array(cv_scores_std2)
plt.fill_between(np.log10(regul_param_range), lower_limit, upper_limit, color="#DDDDDD")

# Creamos el gráfico
plt.title("Curva de aprendizaje")
plt.xlabel("Regularización 10^{-X}"), plt.ylabel("negative MSE"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# * Para ver el perceptron que domina al otro hemos mirado los valores de neg_mean_squared_error, cuanto mas se acerquen a 0 menos error habrá y por tanto será mejor.
# * En nuestro caso el primero percetron(el de una capa con 200 neuronas) tiene mejor valor por lo tanto es el que vamos a elegir para entrenarlo. Esto se debe a que aunque el primer perceptron tiene una única capa oculta tiene suficientes neuronas y puede resolver igual el problema que el segundo perceptron, que tiene 2 capas ocultas, pero menos neuronas en cada capa.

# %% [markdown]
# 5. Entrena el perceptrón elegido con todo el conjunto de datos y genera las predicciones del GDP que hace el perceptrón para todo los países.
# A continuación, píntalas en un diagrama de dispersión frente a los valores observados para el GDP (en el eje Y) y pinta la recta que se genera con la predicción perfecta de todos los valores.
# Detecta países para los cuales el perceptrón a infraestimado más su GDP (aproximadamente). Idem con países donde se ha sobreestimado mucho su GDP. ¿Puedes aventurar alguna razón por la que esos países tienen más (o menos) GDP del que el perceptrón les asigna? ¿Es realmente un problema del perceptrón o eres capaz de ver alguna razón económica, política o social?

# %%
from sklearn.model_selection import cross_val_predict
predicts_scaled = cross_val_predict(mlp1, countries_scaled, target_scaled.ravel(), cv=5)


# escalamos las predicciones para que estén en la escala original
predicts=scaler_y.inverse_transform(predicts_scaled)

# %%
# Dibujamos el histograma de los errores
fig1 = plt.figure()
ax1 = plt.axes()
ax1.hist(np.abs(df['GDP'] - predicts))  # np.abs(boston.target - predicts) es el error en cada ejemplo

plt.title('Distribución del error en valor absoluto')
plt.show()

# %%
fig2 = plt.figure()
ax2 = plt.axes()
# dibujamos los errores: la distancia a la recta indica el nivel de error
ax2.scatter(df['GDP'], predicts) 
# Pintamos la referencia de la predicción perfecta
ax2.plot(df['GDP'], df['GDP'], color='k') 

plt.title('Y Vs Y_pred')
plt.show()

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(countries_scaled, target_scaled.ravel(), test_size=0.3, random_state=333)

plt.plot(y_train)
plt.title('training forecasting GDP')
# Out:
# Text(0.5, 1.0, 'training forecasting GDP')

# %%
mlp1.fit(X_train,y_train)

train_mse = mlp1.predict(X_train)
test_mse = mlp1.predict(X_test)
print ('MSE training', mean_squared_error(train_mse,y_train))
print ('MSE testing', mean_squared_error(test_mse,y_test))
# Out:
# MSE training 0.0034236328991041607
# MSE testing 0.02750637572247933

# %%
train_pred = mlp1.predict(X_train)
test_pred = mlp1.predict(X_test)

plt.plot(train_pred,label='training result')
plt.plot(y_train,color='red', label='prediction target')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('training result')
# Out:
# Text(0.5, 1.0, 'training result')

# %%
plt.plot(test_pred,label='testing result')
plt.plot(y_test,color='red',label='prediction target')
#plt.legend('test,prediction', ncol=2, loc='upper left');
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('testing result')
# Out:
# Text(0.5, 1.0, 'testing result')

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

df = pd.read_csv("countries.csv", decimal=',')
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48.0                         0.00
# 1           28748                      124.6                         1.26
# 2         2381740                       13.8                         0.04
# 3             199                      290.4                        58.29
# 4             468                      152.1                         0.00
#
#   Net migration Infant mortality (per 1000 births)  GDP (USD per capita)  \
# 0         23.06                             163.07                 700.0
# 1         -4.93                              21.52                4500.0
# 2         -0.39                                 31                6000.0
# 3        -20.71                               9.27                8000.0
# 4           6.6                               4.05               19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36.0               3.2      12.13      0.22     87.65       1
# 1         86.5              71.2      21.09      4.42     74.49       3
# 2         70.0              78.1       3.22      0.25     96.53       1
# 3         97.0             259.5         10        15        75       2
# 4        100.0             497.2       2.22         0     97.78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46.6     20.34        0.38     0.24    0.38
# 1     15.11      5.22       0.232    0.188   0.579
# 2     17.14      4.61       0.101      0.6   0.298
# 3     22.46      3.27         NaN      NaN     NaN
# 4      8.71      6.25         NaN      NaN     NaN

# %%
country = df.iloc[:,0]
country
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
sns.barplot(x="GDP (USD per capita)", y="Country", data=df.sort_values(['GDP (USD per capita)'], ascending=False).reset_index(drop=True)[:10]);
